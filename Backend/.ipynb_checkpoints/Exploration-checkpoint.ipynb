# %%
import pandas as pd

# %%
df = pd.read_json('dataset_final.json')
df = pd.json_normalize(df['motions']).set_index('id')
df['title'] = df['title'].str.replace('\nMotie\n:\n', '')
df
# Out:
#                    did                                                url  \
# id
# 2025Z19052  2025D44381  https://www.tweedekamer.nl/kamerstukken/moties...
# 2025Z19055  2025D44384  https://www.tweedekamer.nl/kamerstukken/moties...
# 2025Z19051  2025D44380  https://www.tweedekamer.nl/kamerstukken/moties...
# 2025Z19054  2025D44383  https://www.tweedekamer.nl/kamerstukken/moties...
# 2025Z19053  2025D44382  https://www.tweedekamer.nl/kamerstukken/moties...
# ...                ...                                                ...
# 2024Z18011  2024D43129  https://www.tweedekamer.nl/kamerstukken/moties...
# 2024Z18077  2024D43247  https://www.tweedekamer.nl/kamerstukken/moties...
# 2024Z18079  2024D43249  https://www.tweedekamer.nl/kamerstukken/moties...
# 2024Z18076  2024D43246  https://www.tweedekamer.nl/kamerstukken/moties...
# 2024Z18074  2024D43244  https://www.tweedekamer.nl/kamerstukken/moties...
#
#                                                         title  \
# id
# 2025Z19052              Motie van het lid Ceder c.s. over ...
# 2025Z19055              Motie van het lid Van der Plas ove...
# 2025Z19051              Motie van het lid Ceder over ervoo...
# 2025Z19054              Motie van het lid De Vos over zich...
# 2025Z19053              Motie van het lid De Vos over niet...
# ...                                                       ...
# 2024Z18011                                                NaN
# 2024Z18077              Motie van de leden Stoffer en Cede...
# 2024Z18079                                                NaN
# 2024Z18076                                                NaN
# 2024Z18074              Motie van het lid Crijns over onde...
#
#                                                         votes
# id
# 2025Z19052  [{'party': 'BBB', 'seats': 8, 'vote': 'Voor'},...
# 2025Z19055  [{'party': 'BBB', 'seats': 8, 'vote': 'Voor'},...
# 2025Z19051  [{'party': 'BBB', 'seats': 8, 'vote': 'Tegen'}...
# 2025Z19054  [{'party': 'BBB', 'seats': 8, 'vote': 'Voor'},...
# 2025Z19053  [{'party': 'BBB', 'seats': 8, 'vote': 'Tegen'}...
# ...                                                       ...
# 2024Z18011                                                NaN
# 2024Z18077  [{'party': 'BBB', 'seats': 7, 'vote': 'Voor'},...
# 2024Z18079                                                NaN
# 2024Z18076                                                NaN
# 2024Z18074  [{'party': 'BBB', 'seats': 7, 'vote': 'Voor'},...
#
# [5000 rows x 4 columns]
